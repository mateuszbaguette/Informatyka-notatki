# %% [markdown]
# # T4: Python - napisy.

# %% [markdown]
# 1. **Napisy (łańcuch znaków)** to typ sekwencyjny niezmienny, a więc nie jest możliwe przypisywanie wartości pojedynczym elementom napisu.
#
# 2. Wartości napisów podajemy w apostrofach lub cudzysłowach. Różnica między nimi polega na tym, że dzięki zastosowaniu cudzysłowu można bez przeszkód używać apostrofów.
#
# 3. Przykład:<br>
#      &emsp;**print("Napisy to 'sekwencje' niezmienne." )**<br>
# Po wykonaniu polecenia wyświetli się napis:<br>
#      &emsp;**Napisy to 'sekwencje' niezmienne.**<br>
#
# 4. W innych przypadkach konieczne jest użycie znaku \ przed apostrofem lub cudzysłowem, który ma zostać wyświetlony. Przykłady pokazują różne sytuacje, w których trzeba zastosować \:<br>
# &emsp;**print('Napisy to \\'sekwencje\\' niezmienne.')**<br>
# &emsp;**print("Napisy to \\"sekwencjel\\" niezmienne. ")**<br>
# Po wykonaniu tych poleceń zostaną wypisane napisy:<br>
# &emsp;**Napisy to 'sekwencje' niezmienne.**<br>
# &emsp;**Napisy to "sekwencje" niezmienne.**<br>
#
# 5. W tabeli podano podstawowe informacje na temat napisów, indeksowanie tej sekwencji oraz metody przydatne do przetwarzania tekstów (łańcuchów znaków).
#
# |Konstrukcja języka | Opis|
# |-------------------|-----|
# |**tekst = "programowanie"**|przypisanie wartości zmiennej tekst|
# |**tekst = 'programowanie'**||
# |**tekst[0]** | odwołanie do pierwszego elementu napisu ('p')|
# |**tekst[ -1]** |odwołanie do ostatniego elementu napisu ('e')|
# |**tekst[-2]** | odwołanie do przedostatniego elementu napisu ('i')|
# |**tekst[:5]** |fragment napisu do znaku tekst[4],|
# ||wynik: 'progr'|
# |**tekst[2:]**|fragment napisu od znaku tekst[2],|
# ||wynik: 'ogramowanie'|
# |**tekst[3:8]**| fragment napisu od znaku tekst[3] do znaku tekst[7],|
# ||wynik: 'gramo'|
# |**tekst[2:8:2]**| fragment napisu od znaku tekst[2] do znaku tekst[7] co drugi znak,|
# ||wynik: 'orm'|
# |<b>tekst*=2</b>| wynik: 'programowanieprogramowanie'|
# |**tekst += 'XYZ'**|konkatenacja napisu,|
# ||wynik: 'programowanieXYZ'|
# |**tekst = tekst[:4] + "noz" + tekst[7:]**| konkatenacja napisu,|
# ||wynik: 'prognozowanie'|
# |**tekst = tekst[:3]**| skracanie napisu,|
# ||wynik: 'pro'|
# |**~~tekst[2] = 'w'~~**| **brak możliwości przypisywania**|
# ||**wartości elementom łańcucha**|
# |**len(tekst)**| długość łańcucha (liczba elementów)|
# |**chr(49)**| znak o kodzie ASCII równym 49,|
# ||wynik; '1'|
# |**ord(tekst[0])**| kod ASCII znaku tekst[0],|
# ||wynik: 112|
# |**== != < >**| relacje na napisach (napisy można porównywać)|
# |**'a' in tekst**|sprawdzanie, czy w napisie jest podany|
# |**"z" not in tekst**| znak (lub znaki)|
# |**"ro" in tekst**||
#
#
# 6. Metody do przetwarzania napisów (łańcuchów znaków) — nie modyfikują napisów, a zwracają nowy napis.
#
# |Konstrukcja języka | Opis|
# |-------------------|-----|
# |**tekst = "NAPIS to jest NAPIS"**|
# |**tekst.count('t')** |zwraca liczbę znaków podanych w napisie,|
# |**(tekst * 5).count('t')**| wyniki:|
# ||2|
# ||10|
# |**tekst .find( 'NAPIS')**| odnajduje pierwsze wystąpienie ciągu znaków w napisie,|
# ||jeśli nie znajdzie, zwraca -1,|
# ||wynik: O|
# |**tekst .rfind('NAPIS')**| odnajduje ostatnie wystąpienie ciągu znaków w napisie,|
# ||jeśli nie znajdzie, zwraca —1,|
# ||wynik: 14|
# |**tekst.isdigit()**| sprawdza, czy w napisie są tylko cyfry,|
# ||wynik: False|
# |**tekst.lower()**| zamienia litery na małe,|
# ||wynik: 'napis to jest napis'|
# |**tekst.upper()**| zamienia litery na wielkie,|
# ||wynik: 'NAPIS TO JEST NAPIS'|
# |**tekst.swapcase ( )**| odwraca wielkości liter w napisie,|
# ||wynik: 'napis TO JEST napis'|
# |**tekst.capitalize()**|zamienia pierwszą literę na wielką, a pozostałe na małe,|
# ||wynik: 'Napis to jest napis'|
# |**tekst.strip()**|usuwa białe znaki (tabulatory, spacje, znaki nowego|
# ||wiersza) z lewej i prawej strony napisu|
# |**tekst.lstrip()**|usuwa białe znaki z lewej strony napisu|
# |**tekst.rstrip()**|usuwa białe znaki z prawej strony napisu|
# |**tekst.replace('NAPIS','tekst')**|zamienia wszystkie wystąpienia łańcucha 'NAPIS' na 'tekst',|
# ||wynik: 'tekst to jest tekst'|
# |**tekst.split( )**|konwertuje napis na listę wyrazów,|
# ||wynik: ['NAPIS' 'to', jest', NAPIS']|
#
# 7. Indeksowanie napisów
#
# |Konstrukcja języka | Wynik|
# |-------------------|------|
# |**tekst = 'ABCDEFGH'**|
# |**tekst**| 'ABCDEFGH'|
# |**tekst[2: ]** |'CDEFGH'|
# |**tekst[1::2]**| 'BDFH'|
# |**tekst[::-1]**| 'HGFEDCBA'|
# |**tekst[::-2]**| 'HFDB'|
# |**tekst[::2]**|'ACEG'|
# |**tekst[:3:-2]**|'HF'|
# |**tekst[:4:2]**| 'AC'|
# |**tekst[0:4:2]**|'AC'|
# |**tekst[2:8:2]**|'CEG'|
#
# 8. **Konwersje między typami sekwencyjnymi** - w związku z tym, że typy sekwencyjne są zmienne bądź niezmienne, może zaistnieć potrzeba konwersji między tymi typami. Ponadto przy wczytywaniu i zapisywaniu danych do plików tekstowych może się pojawić konieczność wykonania konwersji, ponieważ w plikach przechowywane są dane typu tekstowego.
#
# 9. W tabeli podano podstawowe metody konwersji między typami sekwencyjnymi.
#
# |Konstrukcja języka |Opis |
# |-------------------|-----|
# |**liczba = int(napis)**| napis na liczbę
# |**napis = str(liczba)**| liczba na napis|
# |**lista = list(napis)**|napis na listę|
# |**lista = list(krotka)**|krotka na listę|
# |**krotka = tuple(napis)**| napis na krotkę|
# |**krotka = tuple(lista)**|lista na krotkę|
# |**''.join(['x','y','z'])**| lista na napis,|
# |**' '.join(['x','y','z'])**| wyniki:|
# ||xyz!|
# ||xyz |
# |**s = list(s)**| konwersja tekstu na listę, a potem listy na tekst,|
# |.|stosuje się, gdy w programie chcemy wykonywać przypisywanie|
# |.|wartości elementom listy, ale wczytaliśmy napis|
# |.||
# |.||
# |**s=''.join(s)**||

# %%
print("Napisy to 'sekwencje' niezmienne." )
print('Napisy to "sekwencje" niezmienne.' )
print('Napisy to \'sekwencje\' niezmienne.')
print("Napisy to \"sekwencje\" niezmienne. ")
# Out:
# Napisy to 'sekwencje' niezmienne.
# Napisy to "sekwencje" niezmienne.
# Napisy to 'sekwencje' niezmienne.
# Napisy to "sekwencje" niezmienne.

# %%
def zad_a(s):
    n = len(s)
    print("zad_a")
    for i in range(n):
        if s[i] != 'm' and s[i] != 'k':
            print(s[i])

def zad_b(s):
    n = len(s)
    j = 0
    for i in range(n):
        if s[i] == 'a':
            j += 1
    return j

def zad_c(s):
    n = len(s)
    k = 0
    for i in range(0, n, 2):
        if s[i] != 'f':
            k += 1
    return k

def zad_d(s):
    n = len(s)
    s = list(s)
    for i in range(n):
        if s[i] == 'o':
            s[i] = 'x'
    s = ''.join(s)       
    return s

def zad_e(s):
    n = len(s)
    s = list(s)
    for i in range(n):
        if s[i] != 'm' and s[i] != 'a':
            s[i] = 'W'
    s=''.join(s)        
    return s
           
zad_a("informatyka")
print("zad_b = ", zad_b("informatyka"))
print("zad_c = ", zad_c("informatyka"))
print("zad_d = ", zad_d("informatyka"))
print("zad_e = ", zad_e("informatyka"))

# %%
def zad_a(s):
    w = ""
    for k in s:
        if k != 'm' and k != 'k':
            w += k
    return w 

def zad_b(s):
    j = 0
    for k in s:
        if k == 'a':
            j += 1
    return j

print("zad_a = ", zad_a("informatyka"))
print("zad_b = ", zad_b("informatyka"))

# %%
# palindrom

def sprawdz1(s):
    dl = len(s)
    for i in range(dl // 2):
        if s[i] != s[dl - i - 1]:
            return False
    return True

def sprawdz2(s):
    return (s == s[::-1])

print(sprawdz1("kajak"))
print(sprawdz2("kajaki"))

# %% [markdown]
# ## ĆWICZENIA
#
#
# 1. Napisz program wykonujący następujące działania na napisach:<br>
# a) obliczenie liczby znaków 'd';<br>
# b) wypisanie znaków w odwrotnej kolejności (czyli od ostatniego znaku do pierwszego);<br>
# c) obliczenie liczby znaków różnych od 'a';<br>
# d) zamiana znaków różnych od 'b' i 'B' na 'a';<br>
# e) wypisanie tylko tych znaków, które są różne od 's';<br>
# f) obliczenie liczby znaków różnych od 'd', które mają indeks podzielny przez 3;<br>
# g) zamiana znaków 'm' na'R'.<br>
#
# 2. Zdania, które są palindromami.Palindromami mogą być również całe zdania. W tym przypadku zwykle nie uwzględnia się spacji. Przykładami takich palindromów są zdania:
#
# **Oko w oko.**
#
# **Zakopane na pokaz.**
#
# **Nogawka jak wagon.**
#
# **Kobyła ma mały bok.**
#
# **Może jutro ta dama sama da tortu jeżom?**
#
# Napisz program, który będzie sprawdzał, czy zawierający spacje tekst jest palindromem.<br>
# Algorytm nie powinien uwzględniać spacji oraz wielkości liter.<br>
#
# 3. Sortowanie tekstu - napisz programy wykonujące sortowanie alfabetyczne łańcucha znaków składającego się z samych cyfr, niezawierającego spacji:<br>
# a) metodą sortowania bąbelkowego;<br>
# b) metodą sortowania przez wstawianie.<br>
#
# 4. Sortowanie listy słów - napisz program sortujący alfabetycznie listę napisów (łańcuchów znaków) składających się z samych cyfr.<br>
