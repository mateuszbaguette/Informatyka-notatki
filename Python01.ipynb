# %% [markdown]
# # T1: Python - wprowadzenie

# %% [markdown]
# 1. **Python** to język programowania wysokiego poziomu. Ma on przejrzystą i zwięzłą składnię.
# Programy są pisane w plikach tekstowych z rozszerzeniem **py**. W języku Python istotna
# jest wielkość liter.
# 2. W kodach programów wykorzystuje się **wcięcia do wydzielania bloków kodu.** Przyjęło
# się stosowanie czterech spacji, ale nie jest to konieczne. Jednak musimy być konsekwentni,
# co oznacza, że jeśli pierwsze wcięcie w funkcji miało trzy spacje, to kolejne wcięcia także
# muszą mieć trzy spacje. Linia bez wcięcia znajdować się będzie poza blokiem.
# 3. Podstawowe konstrukcje języka Python (w tym operacje wejścia-wyjścia, operatory arytmetyczne i logiczne, relacje oraz sposoby zaznaczania komentarzy w kodzie programu).
#
# | Konstrukcja języka | Opis|
# |--------------------|-----|
# | **# komentarz**        |  jednowierszowe komentarze |
# | **"&nbsp;"&nbsp;"**  &nbsp; **'&nbsp;'&nbsp;'**          |  wielowierszowe komentarze ograniczone przez " lub ' |
# | **print("tekst",zmienna)** | wypisanie komunikatu na ekranie,
# |                       |dostępne znaki specjalne: |
# |        |-**\n** (przejście do nowego wiersza)|
# |        |    -**\t** (tabulator) |
# |**a = float(input("podaj liczbę: "))**| wczytywanie zmiennych z klawiatury|
# |**b = int(input("podaj liczbę: "))** |(zmienne są tworzone przez przypisanie|
# |**c = input("podaj tekst: ")**| wartości)|
# |**+&nbsp;-&nbsp;*&nbsp;/&nbsp;** |   operatory arytmetyczne        |
# |**%** |reszta z dzielenia |
# |**//**| dzielenie całkowite |
# |**&nbsp;**&nbsp;**| potęgowanie |
# | **+=&nbsp; -= &nbsp;\*=&nbsp; %=&nbsp; //=&nbsp; \** = &nbsp;** | złożone operatory przypisania |
# |**== &nbsp;!=&nbsp; >&nbsp; <=&nbsp; >=** | relacje |
# |**1 < 3 < 7**| wielokrotne porównania |
# | **and** | |
# |**or** | operatory logiczne |
# |**not** | |
# |
# |**a,b,c = 5,4,8** |wielokrotne przypisanie |
# | | a=5|
# | | b=4|
# | | c=8|
#
# 4. Instrukcje warunkowe
#
# | Konstrukcja języka | Opis |
# |--------------------|------|
# |**if w: instrukcja**| instrukcja warunkowa skrócona|
# |**if w: instrukcja**| instrukcja warunkowa pełna|
# |**else: instrukcja**||
# |**if w1: instrukcja1**| instrukcja warunkowa zagnieżdżona (alternatywa)|
# |**elif w2: instrukcja2**||
# |**elif w3: instrukcja3**||
# |**else: instrukcja4**||
# |**if w1:**| zagnieżdżenie instrukcji warunkowych (koniunkcja)|
# |&emsp;&emsp;**if w2: instrukcja1**||
# |&emsp;&emsp;**else: instrukcja2**||
# | **else: instrukcja3** |     |
#
# 5. Biblioteki i funkcje matematyczne
#
# | Konstrukcja języka | Opis |
# |--------------------|------|
# |**from math import \***| dostęp do biblioteki matematycznej|
# |**a = sqrt(49)**| zastosowanie funkcji **sqrt**, obliczającej pierwiastek|
# |**b = fabs(-8)**| kwadratowy, i funkcji **fabs**, obliczającej wartość bezwzględną,|
# ||wyniki: |
# ||a=7|
# ||b=8|
# |**def pierwiastek(n):**| przykład funkcji zwracającej pojedynczą wartość,|
# |**&emsp;&emsp;return n ** 0.5**| uruchomienie funkcji: pierwiastek(9),|
# ||wynik: 3.0|
# |**def dzialania(a, b):**| przykład funkcji zwracającej dwie wartości (krotkę),|
# |**&emsp;&emsp;return a +b, a - b**| uruchomienie funkcji: dzialania(1, 3),|
# ||wyniki: (4, -2)|

# %%
# alternatywa

def zad_a(x, y, z):
    if x % 2 or y % 2 or z % 2:
        print("TAK")
    else:
        print("NIE")

def zad_b(x, y, z):
    if x % 2:
        print("TAK")
    elif y % 2:
        print("TAK")
    elif z % 2:
        print("TAK")
    else:
        print("NIE")
    
zad_a(4, 6, 2)
zad_b(4, 5, 2)
# Out:
# NIE
# TAK

# %%
# koniunkcja

def zad_a(a, b, c, d):
    if a < 5 and b < 5 and c < 5 and d < 5:
        print("TAK")
    else:
        print("NIE")

def zad_b(a, b, c, d):
    if a < 5:
        if b < 5:
            if c < 5:
                if d < 5: print("TAK")
                else: print("NIE")
            else: print("NIE")
        else: print("NIE")
    else: print("NIE")

zad_a(4, 6, 2, 3)
zad_b(4, 2, 1, 3)
# Out:
# NIE
# TAK

# %%
def pierwiastek(n):
    return n ** 0.5

print(pierwiastek(9))
# Out:
# 3.0

# %%
def dzialania(a, b):
    return a + b, a - b

print(dzialania(1, 3))
# Out:
# (4, -2)

# %%
# algorytm wyznaczający pierwiastki równania liniowego ax+b=0

def rownanie_liniowe(a, b):
    if a != 0:
        x = -b / a
        print("x = ", x)
    elif b == 0:
        print("nieskończenie wiele rozwiązań")
    else: print("równanie sprzeczne")

rownanie_liniowe(-2, 5)
# Out:
# x =  2.5

# %%
# algorytm "delty" rozwiązujący równanie kwadratowe

from math import *

def rownanie_kwadratowe(a, b, c):
    if a == 0:
        print("to nie jest równanie kwadratowe")
    else: 
        delta = b * b - 4 * a * c
        if delta < 0:
            print("równanie nie ma pierwiastków")
        elif delta == 0:
            x = -b / (2 * a)
            print("x = ", x)
        else:    
            x1 = (-b - sqrt(delta)) / (2 * a)
            x2 = (-b + sqrt(delta)) / (2 * a)
            print("x1 = ", x1, "\tx2 = ", x2)

rownanie_kwadratowe(-2, 2, 4)
# Out:
# x1 =  2.0 	x2 =  -1.0

# %% [markdown]
# ## Ćwiczenia:
# 1. Napisz program sprawdzający, czy podana liczba całkowita jest parzysta.
# 2. Napisz program sprawdzający, która z podanych trzech różnych liczb całkowitych — a, b i c — jest największa.
# 3. Napisz programy wyznaczający wartości podanych funkcji:<br>
# a)
# $ f(x) =
#   \begin{cases}
#     2x       & \quad \text{dla } x<1 \\
#     x^4  & \quad \text{dla } x=3 \\
#     \sqrt{x-4}  & \quad \text{dla } x=6 \\
#     0  & \quad \text{dla innych x} \\
#   \end{cases}
# $<br>
# b)
# $ f(x) =
#   \begin{cases}
#     x^3+1       & \quad \text{dla } x<7 \\
#     x-1  & \quad \text{dla } x=7 \\
#     \sqrt{3x}  & \quad \text{dla } x=9 \\
#     -8 x  & \quad \text{dla innych x} \\
#   \end{cases}
# $
# 4. Napisz program sprawdzający, czy odcinki o długościach podanych przez użytkownika mogą tworzyć trójkąt. Bokami tego samego trójkąta mogą być takie odcinki, których suma długości każdej pary odcinków jest większa od długości trzeciego odcinka.
#
# 5. Pole trójkąta można wyznaczyć na podstawie długości jego boków a, b i c, korzystając z wzoru Herona:<br>
# $pole= \sqrt{p(p-a)(p-b)(p-c)}$<br>
# gdzie $p= \frac{a+b+c}{2}$<br>
# Napisz program obliczający pole trójkąta za pomocą wzoru Herona. Nie zapomnij sprawdzić, czy liczba podpierwiastkowa jest nieujemna.
